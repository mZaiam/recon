# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

from automap import AUTOMAP

# %% [markdown]
# ## Learning curve

# %%
train_loss, test_loss = np.load('train_loss.npy'), np.load('test_loss.npy')

# %%
epochs = [_ for _ in range(100)]

plt.plot(epochs, train_loss * 1e2, label='Train')
plt.plot(epochs, test_loss * 1e2, label='Validation')
plt.xlabel('Epochs')
plt.ylabel(r'Loss $(\cdot 10^{-2})$')
plt.title('Learning curve')
plt.legend()
plt.show()

# %% [markdown]
# ## Model avaliation

# %%
n = 128

automap = AUTOMAP(n)

# %%
model = torch.load('n128_b64_lr1e-5_L11e-4_brain_mw20_reducelrplateau_v0.pth', map_location=torch.device('cpu'))

automap.load_state_dict(model)
# Out:
# <All keys matched successfully>

# %%
x_test, y_test = np.load('test_sin_brain.npy'), np.load('test_im_brain.npy')

# %%
sin0, im0 = torch.tensor(x_test[0]), torch.tensor(y_test[0])

wedge_angles = 20

sin0[:, : int(wedge_angles / 2)] = 0
sin0[:, - int(wedge_angles / 2) :] = 0


with torch.no_grad():
    im_pred0 = automap(sin0.reshape(1, n, n))
    im_pred0 = im_pred0.reshape(n, n)
    
fig, ax = plt.subplots(1, 4, figsize=(12, 4))

ax[0].imshow(sin0.reshape(n, n), 'gray')
ax[0].axis('off')
ax[0].set_title('Sinogram')

ax[1].imshow(im0.reshape(n, n), 'gray')
ax[1].axis('off')
ax[1].set_title('Image')

ax[2].imshow(im_pred0.reshape(n, n), 'gray')
ax[2].axis('off')
ax[2].set_title('Reconstruction')

ax[3].imshow((im0 - im_pred0).reshape(n, n), 'gray')
ax[3].axis('off')
ax[3].set_title('Absolute Error')

plt.show()

# %%
sin1, im1 = torch.tensor(x_test[1]), torch.tensor(y_test[1])

wedge_angles = 20

sin1[:, : int(wedge_angles / 2)] = 0
sin1[:, - int(wedge_angles / 2) :] = 0

with torch.no_grad():
    im_pred1 = automap(sin1.reshape(1, n, n))
    im_pred1 = im_pred1.reshape(n, n)
    
fig, ax = plt.subplots(1, 4, figsize=(12, 4))

ax[0].imshow(sin1.reshape(n, n), 'gray')
ax[0].axis('off')
ax[0].set_title('Sinogram')

ax[1].imshow(im1.reshape(n, n), 'gray')
ax[1].axis('off')
ax[1].set_title('Image')

ax[2].imshow(im_pred1.reshape(n, n), 'gray')
ax[2].axis('off')
ax[2].set_title('Reconstruction')

ax[3].imshow((im1 - im_pred1).reshape(n, n), 'gray')
ax[3].axis('off')
ax[3].set_title('Absolute Error')

plt.show()

# %%
sin2, im2 = torch.tensor(x_test[2]), torch.tensor(y_test[2])

wedge_angles = 20

sin2[:, : int(wedge_angles / 2)] = 0
sin2[:, - int(wedge_angles / 2) :] = 0

with torch.no_grad():
    im_pred2 = automap(sin2.reshape(1, n, n))
    im_pred2 = im_pred2.reshape(n, n)
    
fig, ax = plt.subplots(1, 4, figsize=(12, 4))

ax[0].imshow(sin2.reshape(n, n), 'gray')
ax[0].axis('off')
ax[0].set_title('Sinogram')

ax[1].imshow(im2.reshape(n, n), 'gray')
ax[1].axis('off')
ax[1].set_title('Image')

ax[2].imshow(im_pred2.reshape(n, n), 'gray')
ax[2].axis('off')
ax[2].set_title('Reconstruction')

ax[3].imshow((im2 - im_pred2).reshape(n, n), 'gray')
ax[3].axis('off')
ax[3].set_title('Absolute Error')

plt.show()

# %%
sin3, im3 = torch.tensor(x_test[3]), torch.tensor(y_test[3])

wedge_angles = 20

sin3[:, : int(wedge_angles / 2)] = 0
sin3[:, - int(wedge_angles / 2) :] = 0

with torch.no_grad():
    im_pred3 = automap(sin3.reshape(1, n, n))
    im_pred3 = im_pred3.reshape(n, n)
    
fig, ax = plt.subplots(1, 4, figsize=(12, 4))

ax[0].imshow(sin3.reshape(n, n), 'gray')
ax[0].axis('off')
ax[0].set_title('Sinogram')

ax[1].imshow(im3.reshape(n, n), 'gray')
ax[1].axis('off')
ax[1].set_title('Image')

ax[2].imshow(im_pred3.reshape(n, n), 'gray')
ax[2].axis('off')
ax[2].set_title('Reconstruction')

ax[3].imshow((im3 - im_pred3).reshape(n, n), 'gray')
ax[3].axis('off')
ax[3].set_title('Absolute Error')

plt.show()

# %%
sin18, im18 = torch.tensor(x_test[18]), torch.tensor(y_test[18])

wedge_angles = 20

sin18[:, : int(wedge_angles / 2)] = 0
sin18[:, - int(wedge_angles / 2) :] = 0

with torch.no_grad():
    im_pred18 = automap(sin18.reshape(1, n, n))
    im_pred18 = im_pred18.reshape(n, n)
    
fig, ax = plt.subplots(1, 4, figsize=(12, 4))

ax[0].imshow(sin18.reshape(n, n), 'gray')
ax[0].axis('off')
ax[0].set_title('Sinogram')

ax[1].imshow(im18.reshape(n, n), 'gray')
ax[1].axis('off')
ax[1].set_title('Image')

ax[2].imshow(im_pred18.reshape(n, n), 'gray')
ax[2].axis('off')
ax[2].set_title('Reconstruction')

ax[3].imshow((im18 - im_pred18).reshape(n, n), 'gray')
ax[3].axis('off')
ax[3].set_title('Absolute Error')

plt.show()
